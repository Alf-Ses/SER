# %% [markdown]
# # Librosa Features Extraction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import librosa.display
import os
from tqdm import tqdm
import random
import pyloudnorm as pyln

# %%
df = pd.read_csv("train_dev_complete.csv")
df
# Out:
#                                   file     speaker  emotion  source  split
# 0        EMOITA/data/1613671614352.wav  emoita_321    anger  emoita  train
# 1        EMOITA/data/1613658275427.wav  emoita_303    anger  emoita  train
# 2        EMOITA/data/1613324357435.wav  emoita_314    anger  emoita  train
# 3        EMOITA/data/1614274086698.wav  emoita_109    anger  emoita  train
# 4        EMOITA/data/1612982146424.wav  emoita_179    anger  emoita  train
# ...                                ...         ...      ...     ...    ...
# 10673    TESS/data/OAF_cab_neutral.wav    tess_OAF  neutral    tess  train
# 10674  TESS/data/OAF_chain_disgust.wav    tess_OAF  disgust    tess  train
# 10675    TESS/data/OAF_jar_neutral.wav    tess_OAF  neutral    tess  train
# 10676      TESS/data/OAF_lot_angry.wav    tess_OAF    anger    tess  train
# 10677    TESS/data/YAF_met_neutral.wav    tess_YAF  neutral    tess  train
#
# [10678 rows x 5 columns]

# %%
# ---- LUFS
def lufs_normalization(y, sr = 16000, target_lufs = -23.0):
    
    if np.max(np.abs(y)) < 1e5:
        return y
    try:
        meter = pyln.Meter(sr)
        current_lufs = meter.integrated_loudness(y)
        
        y_norm = pyln.normalize.loudness(y, current_lufs, target_lufs)
        return y_norm
    except Exception as e:
        print(f'{e}')
        return y

# ---- PEAK    
def peak_normalization(y, sr = 16000, target_level = 0.95):
    
    if np.max(np.abs(y)) < 1e5:
        return y
    try:
        peak = np.max(np.abs(y))
        y_norm = y / peak * target_level
        
        return y_norm
        
    except Exception as e:
        print(f'{e}')
        return y

# %%
# Function to compute mean and std for each feature, returning a dictionary of statistics of each feature
def compute_mean_and_std(feature_matrix, prefix):
    
    stats = {}
    mean = np.mean(feature_matrix, axis=1)
    std = np.std(feature_matrix, axis=1)
    
    for i, (m, s) in enumerate(zip(mean, std)):
        stats[f"{prefix}_mean_{i+1}"] = m
        stats[f"{prefix}_std_{i+1}"] = s
        
    return stats

# %% [markdown]
# #### Prosodic Features

# %%
# RMS Energy as proxy of loudness
def get_rms(y)-> dict:
    rms = librosa.feature.rms(y=y)
    return compute_mean_and_std(rms, "rms")

# Zero Crossing Rate as proxy of Arousal
def get_zcr(y)-> dict:
    zcr = librosa.feature.zero_crossing_rate(y=y)
    return compute_mean_and_std(zcr, "zcr")

# %% [markdown]
# #### Timbro vocale

# %%
# MFCC for spectral characteristics
def get_mfcc(y, rs = 16000, n_mfcc = 13)-> dict:
    mfcc = librosa.feature.mfcc(y=y, sr=rs, n_mfcc=n_mfcc)
    return compute_mean_and_std(mfcc, "mfcc")

#Delta MFCC for temporal dynamics
def get_delta_mfcc(y, rs = 16000, n_mfcc = 13)-> dict:
    mfcc = librosa.feature.mfcc(y=y, sr=rs, n_mfcc=n_mfcc)
    delta_mfcc = librosa.feature.delta(mfcc)
    return compute_mean_and_std(delta_mfcc, "delta_mfcc")

#Delta-Delta MFCC for acceleration characteristics
def get_delta2_mfcc(y, rs = 16000, n_mfcc = 13)-> dict:
    mfcc = librosa.feature.mfcc(y=y, sr=rs, n_mfcc=n_mfcc)
    delta2_mfcc = librosa.feature.delta(mfcc, order=2)
    return compute_mean_and_std(delta2_mfcc, "delta2_mfcc")

# %%
# Spectral contrast for timbral texture
def get_spectral_contrast(y, rs = 16000)-> dict:
    spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=rs)
    return compute_mean_and_std(spectral_contrast, "spectral_contrast")

# %% [markdown]
# #### Tonal Features

# %%
# Chroma features for harmonic content
def get_chroma(y, rs = 16000)-> dict:
    chroma = librosa.feature.chroma_stft(y=y, sr=rs)
    return compute_mean_and_std(chroma, "chroma")

# Tonnetz for tonal characteristics
def get_tonnetz(y, rs = 16000)-> dict:
    tonnetz = librosa.feature.tonnetz(y=librosa.effects.harmonic(y), sr=rs)
    return compute_mean_and_std(tonnetz, "tonnetz")

# %%
# --- FEATURES EXTRACTOR
SR = 16000

def extract_features(row):
    
    file = row["file"]
    
    y, _ = librosa.load(file, sr=SR)
    
    if y is None or len(y) < 2048:
        return None
    
    full_vector = {}
    
    full_vector["file"] = file
    full_vector["label"] = row["emotion"]
    full_vector["split"] = row["split"]
    
    try:
        full_vector.update(get_rms(y))
        full_vector.update(get_zcr(y))
        full_vector.update(get_mfcc(y))
        full_vector.update(get_delta_mfcc(y))
        full_vector.update(get_delta2_mfcc(y))
        full_vector.update(get_spectral_contrast(y))
        full_vector.update(get_chroma(y))
        full_vector.update(get_tonnetz(y))
        return full_vector
    except Exception as e:
        print(f"Extraction failed for {file}: {e}")
        return None

# %%
if __name__ == "__main__":
    
    features_list = list()
    
    for i, row in tqdm(df.iterrows(), total = df.shape[0]):
        
        features_vector = extract_features(row)
        
        if features_vector is not None:
            features_list.append(features_vector)
            
    librosa_features_df = pd.DataFrame(features_list)
# Out:
#   0%|          | 0/10678 [00:00<?, ?it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=378
#   warnings.warn(
#   0%|          | 2/10678 [00:00<57:45,  3.08it/s]  /Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=453
#   warnings.warn(
#   0%|          | 19/10678 [00:02<22:15,  7.98it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=430
#   warnings.warn(
#   0%|          | 32/10678 [00:04<22:30,  7.88it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=502
#   warnings.warn(
#   0%|          | 36/10678 [00:04<19:38,  9.03it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=508
#   warnings.warn(
#   1%|          | 71/10678 [00:08<20:31,  8.61it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=436
#   warnings.warn(
#   1%|          | 75/10678 [00:09<19:23,  9.11it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=489
#   warnings.warn(
#   1%|          | 85/10678 [00:10<22:53,  7.71it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=445
#   warnings.warn(
#   1%|          | 109/10678 [00:12<19:51,  8.87it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=494
#   warnings.warn(
#   1%|          | 128/10678 [00:15<17:49,  9.86it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=346
#   warnings.warn(
#   1%|▏         | 139/10678 [00:16<22:43,  7.73it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=492
#   warnings.warn(
# /Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=389
#   warnings.warn(
#   1%|▏         | 145/10678 [00:17<19:33,  8.98it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=474
#   warnings.warn(
#   1%|▏         | 154/10678 [00:18<22:23,  7.84it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=433
#   warnings.warn(
# /Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=399
#   warnings.warn(
#   1%|▏         | 156/10678 [00:18<18:07,  9.67it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=279
#   warnings.warn(
#   2%|▏         | 165/10678 [00:19<19:41,  8.90it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=456
#   warnings.warn(
#   2%|▏         | 173/10678 [00:20<18:34,  9.42it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=491
#   warnings.warn(
# /Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=482
#   warnings.warn(
#   2%|▏         | 175/10678 [00:20<16:59, 10.30it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=442
#   warnings.warn(
#   2%|▏         | 183/10678 [00:21<19:30,  8.97it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=497
#   warnings.warn(
#   2%|▏         | 187/10678 [00:21<18:05,  9.67it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=387
#   warnings.warn(
#   2%|▏         | 193/10678 [00:22<16:14, 10.76it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=459
#   warnings.warn(
#   2%|▏         | 198/10678 [00:22<20:50,  8.38it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=503
#   warnings.warn(
#   2%|▏         | 225/10678 [00:25<19:59,  8.72it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=490
#   warnings.warn(
#   2%|▏         | 230/10678 [00:26<18:30,  9.41it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=485
#   warnings.warn(
#   2%|▏         | 233/10678 [00:26<18:02,  9.65it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=505
#   warnings.warn(
#   2%|▏         | 239/10678 [00:27<18:25,  9.45it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=398
#   warnings.warn(
#   2%|▏         | 260/10678 [00:29<21:41,  8.00it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=410
#   warnings.warn(
#   3%|▎         | 267/10678 [00:30<21:57,  7.90it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=424
#   warnings.warn(
#   3%|▎         | 283/10678 [00:32<20:19,  8.52it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=305
#   warnings.warn(
#   3%|▎         | 285/10678 [00:32<18:05,  9.58it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=401
#   warnings.warn(
#   3%|▎         | 301/10678 [00:34<22:16,  7.76it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=452
#   warnings.warn(
#   3%|▎         | 313/10678 [00:35<19:36,  8.81it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=413
#   warnings.warn(
#   3%|▎         | 323/10678 [00:36<20:57,  8.24it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=478
#   warnings.warn(
#   3%|▎         | 325/10678 [00:37<19:40,  8.77it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=450
#   warnings.warn(
#   3%|▎         | 327/10678 [00:37<18:57,  9.10it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=471
#   warnings.warn(
#   3%|▎         | 346/10678 [00:39<19:58,  8.62it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=488
#   warnings.warn(
#   3%|▎         | 351/10678 [00:40<17:36,  9.78it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=421
#   warnings.warn(
# /Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=375
#   warnings.warn(
#   3%|▎         | 359/10678 [00:40<19:54,  8.64it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=500
#   warnings.warn(
#   4%|▎         | 385/10678 [00:43<20:00,  8.58it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=404
#   warnings.warn(
#   4%|▎         | 390/10678 [00:44<19:39,  8.73it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=468
#   warnings.warn(
#   4%|▍         | 410/10678 [00:46<18:48,  9.10it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=462
#   warnings.warn(
#   4%|▍         | 423/10678 [00:48<20:17,  8.42it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=511
#   warnings.warn(
#   4%|▍         | 458/10678 [00:52<19:35,  8.69it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=477
#   warnings.warn(
#   5%|▍         | 502/10678 [00:57<16:09, 10.49it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=334
#   warnings.warn(
#   5%|▌         | 549/10678 [01:02<19:18,  8.74it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=422
#   warnings.warn(
#   5%|▌         | 565/10678 [01:04<21:10,  7.96it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=506
#   warnings.warn(
#   6%|▌         | 616/10678 [01:11<23:25,  7.16it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=392
#   warnings.warn(
#   7%|▋         | 772/10678 [01:30<21:02,  7.85it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=448
#   warnings.warn(
#   9%|▊         | 911/10678 [01:49<21:20,  7.63it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=447
#   warnings.warn(
#   9%|▉         | 972/10678 [01:58<25:46,  6.28it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=441
#   warnings.warn(
#   9%|▉         | 981/10678 [01:59<22:22,  7.22it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=363
#   warnings.warn(
#  10%|▉         | 1044/10678 [02:07<24:51,  6.46it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=323
#   warnings.warn(
#  11%|█         | 1195/10678 [02:28<18:24,  8.59it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=426
#   warnings.warn(
#  12%|█▏        | 1244/10678 [02:34<25:50,  6.09it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=360
#   warnings.warn(
#  14%|█▍        | 1484/10678 [03:06<18:23,  8.33it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=428
#   warnings.warn(
#  14%|█▍        | 1504/10678 [03:09<17:36,  8.69it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=465
#   warnings.warn(
#  14%|█▍        | 1527/10678 [03:12<22:10,  6.88it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=343
#   warnings.warn(
#  15%|█▍        | 1585/10678 [03:19<16:39,  9.09it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=479
#   warnings.warn(
#  16%|█▌        | 1693/10678 [03:33<17:18,  8.66it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=337
#   warnings.warn(
#  16%|█▌        | 1696/10678 [03:33<16:40,  8.98it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=328
#   warnings.warn(
#  16%|█▌        | 1711/10678 [03:35<14:46, 10.11it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=317
#   warnings.warn(
#  16%|█▌        | 1735/10678 [03:38<16:09,  9.22it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=294
#   warnings.warn(
#  17%|█▋        | 1794/10678 [03:44<16:11,  9.15it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=355
#   warnings.warn(
#  17%|█▋        | 1804/10678 [03:45<15:40,  9.44it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=418
#   warnings.warn(
#  18%|█▊        | 1878/10678 [03:53<17:36,  8.33it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=507
#   warnings.warn(
#  18%|█▊        | 1906/10678 [03:56<16:05,  9.08it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=443
#   warnings.warn(
#  18%|█▊        | 1944/10678 [04:01<16:00,  9.10it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=438
#   warnings.warn(
#  19%|█▉        | 2042/10678 [04:12<16:57,  8.49it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=288
#   warnings.warn(
#  19%|█▉        | 2045/10678 [04:12<14:25,  9.97it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=510
#   warnings.warn(
#  19%|█▉        | 2049/10678 [04:12<14:41,  9.79it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=457
#   warnings.warn(
#  19%|█▉        | 2069/10678 [04:15<16:42,  8.59it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=439
#   warnings.warn(
#  20%|██        | 2142/10678 [04:23<16:13,  8.77it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=499
#   warnings.warn(
#  21%|██        | 2216/10678 [04:31<13:57, 10.11it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=493
#   warnings.warn(
#  21%|██        | 2261/10678 [04:36<15:56,  8.80it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=416
#   warnings.warn(
#  22%|██▏       | 2306/10678 [04:41<16:44,  8.33it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=454
#   warnings.warn(
#  23%|██▎       | 2408/10678 [04:54<16:51,  8.18it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=302
#   warnings.warn(
#  25%|██▍       | 2635/10678 [05:21<15:57,  8.40it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=372
#   warnings.warn(
#  25%|██▍       | 2659/10678 [05:24<16:14,  8.23it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=463
#   warnings.warn(
#  26%|██▌       | 2748/10678 [05:34<14:28,  9.13it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=400
#   warnings.warn(
#  26%|██▌       | 2781/10678 [05:38<16:38,  7.91it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=189
#   warnings.warn(
#  26%|██▋       | 2810/10678 [05:41<15:21,  8.54it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=464
#   warnings.warn(
#  27%|██▋       | 2923/10678 [05:56<16:44,  7.72it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=407
#   warnings.warn(
#  28%|██▊       | 3021/10678 [06:10<17:54,  7.13it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=366
#   warnings.warn(
#  31%|███       | 3335/10678 [06:52<16:50,  7.27it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=340
#   warnings.warn(
#  33%|███▎      | 3478/10678 [07:10<15:43,  7.63it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=369
#   warnings.warn(
#  34%|███▍      | 3653/10678 [07:31<16:15,  7.20it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=395
#   warnings.warn(
#  35%|███▌      | 3787/10678 [07:46<14:43,  7.80it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=460
#   warnings.warn(
#  36%|███▌      | 3794/10678 [07:47<14:02,  8.17it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=253
#   warnings.warn(
#  37%|███▋      | 3991/10678 [08:11<12:43,  8.76it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=467
#   warnings.warn(
#  37%|███▋      | 3997/10678 [08:12<13:47,  8.08it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=495
#   warnings.warn(
#  38%|███▊      | 4021/10678 [08:15<13:51,  8.01it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=381
#   warnings.warn(
#  38%|███▊      | 4035/10678 [08:17<12:35,  8.79it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=390
#   warnings.warn(
#  38%|███▊      | 4039/10678 [08:17<13:02,  8.49it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=427
#   warnings.warn(
#  38%|███▊      | 4078/10678 [08:22<13:14,  8.30it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=299
#   warnings.warn(
#  39%|███▉      | 4138/10678 [08:29<12:14,  8.90it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=316
#   warnings.warn(
#  39%|███▉      | 4189/10678 [08:34<12:19,  8.77it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=481
#   warnings.warn(
#  39%|███▉      | 4192/10678 [08:34<12:18,  8.79it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=233
#   warnings.warn(
#  39%|███▉      | 4203/10678 [08:36<13:26,  8.03it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=331
#   warnings.warn(
#  40%|███▉      | 4222/10678 [08:38<12:29,  8.62it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=475
#   warnings.warn(
#  45%|████▍     | 4794/10678 [09:52<12:06,  8.09it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=358
#   warnings.warn(
#  46%|████▌     | 4913/10678 [10:05<10:33,  9.10it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=352
#   warnings.warn(
#  46%|████▌     | 4919/10678 [10:06<11:02,  8.70it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=480
#   warnings.warn(
#  46%|████▌     | 4923/10678 [10:06<10:23,  9.23it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=309
#   warnings.warn(
#  47%|████▋     | 5059/10678 [10:22<10:53,  8.60it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=350
#   warnings.warn(
#  47%|████▋     | 5072/10678 [10:24<12:44,  7.33it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=349
#   warnings.warn(
#  48%|████▊     | 5107/10678 [10:28<10:21,  8.96it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=384
#   warnings.warn(
#  49%|████▊     | 5202/10678 [10:40<13:06,  6.96it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=429
#   warnings.warn(
#  49%|████▉     | 5229/10678 [10:44<11:41,  7.77it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=379
#   warnings.warn(
#  49%|████▉     | 5248/10678 [10:46<11:07,  8.13it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=308
#   warnings.warn(
#  52%|█████▏    | 5587/10678 [11:30<09:54,  8.57it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=364
#   warnings.warn(
#  70%|███████   | 7508/10678 [16:02<07:36,  6.95it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=414
#   warnings.warn(
#  71%|███████   | 7585/10678 [16:13<07:00,  7.36it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=408
#   warnings.warn(
#  72%|███████▏  | 7699/10678 [16:28<06:24,  7.75it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=504
#   warnings.warn(
#  73%|███████▎  | 7769/10678 [16:37<06:16,  7.72it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=470
#   warnings.warn(
#  73%|███████▎  | 7817/10678 [16:44<06:16,  7.60it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=472
#   warnings.warn(
#  74%|███████▍  | 7891/10678 [16:54<04:10, 11.14it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=356
#   warnings.warn(
#  74%|███████▍  | 7893/10678 [16:54<04:01, 11.55it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=394
#   warnings.warn(
#  74%|███████▍  | 7895/10678 [16:54<04:01, 11.52it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=473
#   warnings.warn(
# /Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=469
#   warnings.warn(
#  74%|███████▍  | 7897/10678 [16:54<03:56, 11.75it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=411
#   warnings.warn(
#  74%|███████▍  | 7903/10678 [16:55<03:49, 12.12it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=425
#   warnings.warn(
#  74%|███████▍  | 7905/10678 [16:55<03:49, 12.08it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=368
#   warnings.warn(
#  74%|███████▍  | 7909/10678 [16:55<03:50, 12.03it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=432
#   warnings.warn(
# /Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=486
#   warnings.warn(
#  74%|███████▍  | 7919/10678 [16:56<04:00, 11.45it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=385
#   warnings.warn(
#  74%|███████▍  | 7927/10678 [16:57<04:00, 11.44it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=476
#   warnings.warn(
#  74%|███████▍  | 7935/10678 [16:57<03:58, 11.48it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=423
#   warnings.warn(
#  74%|███████▍  | 7943/10678 [16:58<03:55, 11.59it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=461
#   warnings.warn(
#  74%|███████▍  | 7951/10678 [16:59<04:04, 11.14it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=415
#   warnings.warn(
#  75%|███████▍  | 7959/10678 [16:59<04:02, 11.21it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=417
#   warnings.warn(
#  75%|███████▍  | 7971/10678 [17:01<04:12, 10.72it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=501
#   warnings.warn(
#  75%|███████▍  | 7983/10678 [17:02<04:11, 10.70it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=345
#   warnings.warn(
#  75%|███████▍  | 7993/10678 [17:03<03:54, 11.46it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=371
#   warnings.warn(
#  75%|███████▍  | 7999/10678 [17:03<03:48, 11.75it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=359
#   warnings.warn(
# /Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=405
#   warnings.warn(
#  75%|███████▍  | 8001/10678 [17:03<03:36, 12.35it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=466
#   warnings.warn(
#  75%|███████▍  | 8005/10678 [17:04<03:39, 12.20it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=402
#   warnings.warn(
# /Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=496
#   warnings.warn(
#  75%|███████▌  | 8029/10678 [17:06<03:54, 11.28it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=431
#   warnings.warn(
#  75%|███████▌  | 8035/10678 [17:06<03:56, 11.17it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=435
#   warnings.warn(
#  75%|███████▌  | 8041/10678 [17:07<04:11, 10.49it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=386
#   warnings.warn(
#  75%|███████▌  | 8061/10678 [17:09<03:59, 10.92it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=347
#   warnings.warn(
#  76%|███████▌  | 8067/10678 [17:09<03:55, 11.10it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=376
#   warnings.warn(
#  76%|███████▌  | 8073/10678 [17:10<03:45, 11.55it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=383
#   warnings.warn(
#  76%|███████▌  | 8083/10678 [17:11<03:53, 11.13it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=484
#   warnings.warn(
#  76%|███████▌  | 8085/10678 [17:11<03:51, 11.20it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=446
#   warnings.warn(
#  76%|███████▌  | 8087/10678 [17:11<03:49, 11.27it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=396
#   warnings.warn(
#  76%|███████▌  | 8089/10678 [17:11<03:44, 11.54it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=370
#   warnings.warn(
#  76%|███████▌  | 8091/10678 [17:11<03:43, 11.56it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=509
#   warnings.warn(
#  76%|███████▌  | 8101/10678 [17:12<03:44, 11.49it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=406
#   warnings.warn(
#  76%|███████▌  | 8107/10678 [17:13<03:53, 11.03it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=380
#   warnings.warn(
#  76%|███████▌  | 8109/10678 [17:13<03:48, 11.23it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=354
#   warnings.warn(
#  76%|███████▋  | 8149/10678 [17:16<03:51, 10.92it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=373
#   warnings.warn(
#  76%|███████▋  | 8157/10678 [17:17<03:36, 11.64it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=377
#   warnings.warn(
#  76%|███████▋  | 8163/10678 [17:18<03:33, 11.78it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=419
#   warnings.warn(
#  77%|███████▋  | 8175/10678 [17:19<03:44, 11.14it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=357
#   warnings.warn(
#  77%|███████▋  | 8225/10678 [17:23<03:32, 11.53it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=397
#   warnings.warn(
#  77%|███████▋  | 8245/10678 [17:25<03:54, 10.38it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=487
#   warnings.warn(
#  77%|███████▋  | 8259/10678 [17:26<03:24, 11.82it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=498
#   warnings.warn(
#  77%|███████▋  | 8263/10678 [17:26<03:26, 11.72it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=449
#   warnings.warn(
#  77%|███████▋  | 8265/10678 [17:27<03:23, 11.83it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=374
#   warnings.warn(
#  77%|███████▋  | 8271/10678 [17:27<03:26, 11.64it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=458
#   warnings.warn(
#  78%|███████▊  | 8277/10678 [17:28<03:17, 12.17it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=391
#   warnings.warn(
#  78%|███████▊  | 8283/10678 [17:28<03:20, 11.93it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=367
#   warnings.warn(
#  78%|███████▊  | 8297/10678 [17:29<03:22, 11.74it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=444
#   warnings.warn(
#  78%|███████▊  | 8357/10678 [17:35<03:24, 11.36it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=455
#   warnings.warn(
#  78%|███████▊  | 8377/10678 [17:36<03:30, 10.92it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=440
#   warnings.warn(
#  79%|███████▊  | 8405/10678 [17:39<03:16, 11.57it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=412
#   warnings.warn(
#  79%|███████▉  | 8417/10678 [17:40<03:28, 10.82it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=434
#   warnings.warn(
#  79%|███████▉  | 8455/10678 [17:43<03:08, 11.80it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=325
#   warnings.warn(
#  79%|███████▉  | 8461/10678 [17:44<03:04, 12.04it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=344
#   warnings.warn(
#  79%|███████▉  | 8477/10678 [17:45<03:06, 11.78it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=483
#   warnings.warn(
#  79%|███████▉  | 8479/10678 [17:45<03:07, 11.71it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=409
#   warnings.warn(
#  79%|███████▉  | 8485/10678 [17:46<03:08, 11.63it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=362
#   warnings.warn(
#  80%|████████  | 8591/10678 [17:55<03:02, 11.43it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=420
#   warnings.warn(
#  81%|████████  | 8629/10678 [17:58<03:03, 11.19it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=451
#   warnings.warn(
#  81%|████████  | 8631/10678 [17:59<02:56, 11.57it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=332
#   warnings.warn(
#  82%|████████▏ | 8719/10678 [18:06<02:52, 11.34it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=348
#   warnings.warn(
#  83%|████████▎ | 8841/10678 [18:17<02:33, 12.00it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=361
#   warnings.warn(
#  83%|████████▎ | 8857/10678 [18:18<02:41, 11.27it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=403
#   warnings.warn(
#  84%|████████▎ | 8933/10678 [18:25<02:45, 10.56it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=342
#   warnings.warn(
#  84%|████████▍ | 8977/10678 [18:29<02:33, 11.08it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=388
#   warnings.warn(
#  87%|████████▋ | 9338/10678 [19:01<02:02, 10.90it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=330
#   warnings.warn(
#  88%|████████▊ | 9384/10678 [19:05<01:46, 12.11it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=365
#   warnings.warn(
#  89%|████████▉ | 9526/10678 [19:18<01:49, 10.48it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=393
#   warnings.warn(
#  90%|█████████ | 9662/10678 [19:30<01:30, 11.28it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=314
#   warnings.warn(
#  91%|█████████ | 9666/10678 [19:31<01:29, 11.31it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=351
#   warnings.warn(
#  92%|█████████▏| 9806/10678 [19:43<01:17, 11.27it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=329
#   warnings.warn(
#  93%|█████████▎| 9908/10678 [19:52<01:07, 11.46it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=382
#   warnings.warn(
#  98%|█████████▊| 10454/10678 [20:40<00:20, 11.07it/s]/Users/alfred/Documents/SER/.venv/lib/python3.14/site-packages/librosa/core/spectrum.py:266: UserWarning: n_fft=512 is too large for input signal of length=437
#   warnings.warn(
# 100%|██████████| 10678/10678 [21:00<00:00,  8.47it/s]

# %%
librosa_features_df
# Out:
#                                   file    label  split  rms_mean_1  rms_std_1  \
# 0        EMOITA/data/1613671614352.wav    anger  train    0.024803   0.018837
# 1        EMOITA/data/1613658275427.wav    anger  train    0.098870   0.089459
# 2        EMOITA/data/1613324357435.wav    anger  train    0.061353   0.076801
# 3        EMOITA/data/1614274086698.wav    anger  train    0.052951   0.055620
# 4        EMOITA/data/1612982146424.wav    anger  train    0.029244   0.029896
# ...                                ...      ...    ...         ...        ...
# 10673    TESS/data/OAF_cab_neutral.wav  neutral  train    0.011656   0.006050
# 10674  TESS/data/OAF_chain_disgust.wav  disgust  train    0.011848   0.010605
# 10675    TESS/data/OAF_jar_neutral.wav  neutral  train    0.012574   0.005751
# 10676      TESS/data/OAF_lot_angry.wav    anger  train    0.038752   0.028055
# 10677    TESS/data/YAF_met_neutral.wav  neutral  train    0.018589   0.010874
#
#        zcr_mean_1  zcr_std_1  mfcc_mean_1  mfcc_std_1  mfcc_mean_2  ...  \
# 0        0.094025   0.041726  -386.987579  109.523575    92.180084  ...
# 1        0.236770   0.135869  -222.974136  138.506271    36.672932  ...
# 2        0.186284   0.138848  -334.634979  163.107941    46.877239  ...
# 3        0.110824   0.083089  -337.719818  111.294464    59.848953  ...
# 4        0.227802   0.121835  -348.929504  174.111023    55.746693  ...
# ...           ...        ...          ...         ...          ...  ...
# 10673    0.099544   0.111094  -473.686096  104.024330    64.592720  ...
# 10674    0.154508   0.182570  -458.265991  133.222198    64.057930  ...
# 10675    0.102967   0.107745  -495.947906   89.606804    82.702103  ...
# 10676    0.110754   0.108246  -377.398712   78.184418    52.664715  ...
# 10677    0.171828   0.219099  -422.939484   75.632607    70.471565  ...
#
#        tonnetz_mean_2  tonnetz_std_2  tonnetz_mean_3  tonnetz_std_3  \
# 0           -0.000301       0.162367       -0.027398       0.170889
# 1            0.006156       0.097414        0.011117       0.142223
# 2           -0.026362       0.115640        0.036014       0.208363
# 3            0.037641       0.121842       -0.049022       0.195470
# 4           -0.000657       0.043193        0.012547       0.135329
# ...               ...            ...             ...            ...
# 10673        0.057049       0.242782        0.269023       0.240616
# 10674       -0.008685       0.104257       -0.057601       0.151587
# 10675       -0.118085       0.335404        0.128877       0.280124
# 10676        0.071702       0.153994       -0.003404       0.254154
# 10677       -0.204155       0.310060        0.069205       0.194120
#
#        tonnetz_mean_4  tonnetz_std_4  tonnetz_mean_5  tonnetz_std_5  \
# 0           -0.027288       0.276434        0.049214       0.057863
# 1            0.002411       0.168923        0.012504       0.056174
# 2           -0.084484       0.179091       -0.034872       0.057218
# 3            0.020855       0.160576       -0.014241       0.067783
# 4            0.029270       0.073095        0.026593       0.035770
# ...               ...            ...             ...            ...
# 10673       -0.191205       0.226487        0.110749       0.083580
# 10674        0.003219       0.162539        0.012875       0.046664
# 10675       -0.300117       0.251332        0.103346       0.093092
# 10676       -0.233565       0.279082       -0.071062       0.094332
# 10677       -0.364562       0.223244        0.070270       0.068468
#
#        tonnetz_mean_6  tonnetz_std_6
# 0            0.035949       0.069892
# 1           -0.006190       0.045487
# 2           -0.022433       0.060650
# 3           -0.028701       0.060781
# 4            0.049189       0.038273
# ...               ...            ...
# 10673       -0.006572       0.107392
# 10674        0.006841       0.055044
# 10675        0.046550       0.116739
# 10676       -0.015076       0.110328
# 10677        0.094386       0.102613
#
# [10678 rows x 135 columns]

# %%
output_dir = "TRAINING_ML"

if os.path.exists(output_dir):
    print("Folder already exists")
else:
    print("Folder created.")
    os.mkdir(output_dir)
    
output_path = os.path.join(output_dir, "LIBROSA_FEATURES.pkl")

if os.path.exists(output_path):
    print("file already exists")
else:
    print("File created.")
    librosa_features_df.to_pickle(output_path)
# Out:
# Folder already exists
# File created.

# %% [markdown]
# # OpenSMILE Features Extraction

# %%
import opensmile

# %%
SR = 16000
smile = opensmile.Smile(
    feature_set = opensmile.FeatureSet.eGeMAPSv02,
    feature_level = opensmile.FeatureLevel.Functionals
)

def opensmile_features(file):
    
    try:
        y, _ = librosa.load(file, sr = SR)
        
        if len(y) < 2048:
            return None
        
        features = smile.process_signal(y,SR)
        features_vector = features.reset_index(drop=True).iloc[0].to_dict()
        
        return features_vector
    except Exception as e:
        print(f"{e}")
        return None
    
def opensmile_features_NORM(file):
    
    try:
        y_raw, _ = librosa.load(file, sr = SR)
        
        if len(y_raw) < 2048:
            return None
        
        y = peak_normalization(y_raw)
        
        features = smile.process_signal(y,SR)
        features_vector = features.reset_index(drop=True).iloc[0].to_dict()
        
        return features_vector
    except Exception as e:
        print(f"{e}")
        return None

# %%
def extract_opensmile_features(row):
    
    file = row["file"]
    
    full_vector = {}
    
    full_vector["file"] = file
    full_vector["label"] = row["emotion"]
    full_vector["split"] = row["split"]
    
    try:
        full_vector.update(opensmile_features(file))
        
        return full_vector
    except Exception as e:
        print(f"Extraction failed for {file}: {e}")
        return None

# %%
if __name__ == "__main__":
    
    features_list = list()
    
    for i, row in tqdm(df.iterrows(), total = df.shape[0]):
        
        features_vector = extract_opensmile_features(row)
        
        if features_vector is not None:
            features_list.append(features_vector)
            
    opensmile_features_df = pd.DataFrame(features_list)
# Out:
# 100%|██████████| 10678/10678 [08:53<00:00, 20.02it/s]

# %%
opensmile_features_df
# Out:
#                                   file    label  split  \
# 0        EMOITA/data/1613671614352.wav    anger  train
# 1        EMOITA/data/1613658275427.wav    anger  train
# 2        EMOITA/data/1613324357435.wav    anger  train
# 3        EMOITA/data/1614274086698.wav    anger  train
# 4        EMOITA/data/1612982146424.wav    anger  train
# ...                                ...      ...    ...
# 10673    TESS/data/OAF_cab_neutral.wav  neutral  train
# 10674  TESS/data/OAF_chain_disgust.wav  disgust  train
# 10675    TESS/data/OAF_jar_neutral.wav  neutral  train
# 10676      TESS/data/OAF_lot_angry.wav    anger  train
# 10677    TESS/data/YAF_met_neutral.wav  neutral  train
#
#        F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              38.082653
# 1                              40.416210
# 2                              36.352093
# 3                              39.521694
# 4                              34.608627
# ...                                  ...
# 10673                          33.587734
# 10674                          32.935085
# 10675                          33.239281
# 10676                          39.684753
# 10677                          33.191181
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                    0.070298
# 1                                    0.120092
# 2                                    0.073894
# 3                                    0.132925
# 4                                    0.200003
# ...                                       ...
# 10673                                0.013397
# 10674                                0.090005
# 10675                                0.018863
# 10676                                0.053821
# 10677                                0.012730
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       36.122330
# 1                                       35.865879
# 2                                       32.938965
# 3                                       33.641102
# 4                                       30.287437
# ...                                           ...
# 10673                                   33.257698
# 10674                                   30.599874
# 10675                                   32.946789
# 10676                                   38.062737
# 10677                                   32.967422
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       39.153728
# 1                                       40.851280
# 2                                       37.385406
# 3                                       41.257381
# 4                                       33.143135
# ...                                           ...
# 10673                                   33.573410
# 10674                                   32.400887
# 10675                                   33.233498
# 10676                                   40.380672
# 10677                                   33.209473
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       39.698322
# 1                                       43.643463
# 2                                       38.716221
# 3                                       44.157024
# 4                                       35.956718
# ...                                           ...
# 10673                                   33.801815
# 10674                                   35.419796
# 10675                                   33.606705
# 10676                                   41.368752
# 10677                                   33.540462
#
#        F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                      3.575993
# 1                                      7.777584
# 2                                      5.777256
# 3                                     10.515923
# 4                                      5.669281
# ...                                         ...
# 10673                                  0.544117
# 10674                                  4.819921
# 10675                                  0.659916
# 10676                                  3.306015
# 10677                                  0.573040
#
#        F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  ...  \
# 0                                        13.681193  ...
# 1                                       134.605118  ...
# 2                                        36.450661  ...
# 3                                        95.706833  ...
# 4                                      2856.700928  ...
# ...                                            ...  ...
# 10673                                    11.546522  ...
# 10674                                    55.039375  ...
# 10675                                    21.448641  ...
# 10676                                    37.567173  ...
# 10677                                    47.889469  ...
#
#        slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# 0                       0.043457                      0.024475
# 1                       0.082220                     -0.000170
# 2                       0.039326                      0.018660
# 3                       0.069682                      0.005402
# 4                       0.036268                      0.003279
# ...                          ...                           ...
# 10673                  -0.036753                      0.025578
# 10674                  -0.025782                      0.018447
# 10675                  -0.043057                      0.024206
# 10676                  -0.023124                      0.012767
# 10677                  -0.016006                      0.016694
#
#        spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# 0                         0.013053             4.697987              2.097902
# 1                         0.249301             4.437870              2.702703
# 2                         0.035453             3.888889              2.298851
# 3                         0.113051             4.635762              2.702703
# 4                         0.147435             3.319502              1.271186
# ...                            ...                  ...                   ...
# 10673                     0.020441             2.645503              1.092896
# 10674                     0.033190             2.145923              1.754386
# 10675                     0.018796             1.960784              1.010101
# 10676                     0.059855             2.500000              1.290323
# 10677                     0.026538             3.045686              1.562500
#
#        MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# 0                        0.420000                      0.143527
# 1                        0.203333                      0.144760
# 2                        0.247500                      0.218561
# 3                        0.230000                      0.127574
# 4                        0.130000                      0.141657
# ...                           ...                           ...
# 10673                    0.655000                      0.335000
# 10674                    0.330000                      0.384773
# 10675                    0.810000                      0.370000
# 10676                    0.585000                      0.285000
# 10677                    0.420000                      0.398246
#
#        MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# 0                       0.055000                     0.035000
# 1                       0.144444                     0.229594
# 2                       0.220000                     0.165731
# 3                       0.186000                     0.204900
# 4                       0.475000                     0.397146
# ...                          ...                          ...
# 10673                   0.240000                     0.030000
# 10674                   0.215000                     0.127574
# 10675                   0.160000                     0.040000
# 10676                   0.110000                     0.028284
# 10677                   0.193333                     0.080554
#
#        equivalentSoundLevel_dBp
# 0                    -29.997206
# 1                    -17.485447
# 2                    -20.091305
# 3                    -22.264414
# 4                    -27.532452
# ...                         ...
# 10673                -37.568298
# 10674                -35.905819
# 10675                -37.107567
# 10676                -26.319199
# 10677                -33.309395
#
# [10678 rows x 91 columns]

# %%
output_dir = "TRAINING_ML"

if os.path.exists(output_dir):
    print("Folder already exists")
else:
    print("Folder created.")
    os.mkdir(output_dir)
    
output_path = os.path.join(output_dir, "OPENSMILE_FEATURES.pkl")

if os.path.exists(output_path):
    print("file already exists")
else:
    print("File created.")
    opensmile_features_df.to_pickle(output_path)
# Out:
# Folder already exists
# File created.

# %%
# ---- LUFS
def lufs_normalization(y, sr = 16000, target_lufs = -23.0):
    
    if np.max(np.abs(y)) < 1e5:
        return y
    try:
        meter = pyln.Meter(sr)
        current_lufs = meter.integrated_loudness(y)
        
        y_norm = pyln.normalize.loudness(y, current_lufs, target_lufs)
        return y_norm
    except Exception as e:
        print(f'{e}')
        return y

# ---- PEAK    
def peak_normalization(y, sr = 16000, target_level = 0.95):
    
    if np.max(np.abs(y)) < 1e5:
        return y
    try:
        peak = np.max(np.abs(y))
        y_norm = y / peak * target_level
        
        return y_norm
        
    except Exception as e:
        print(f'{e}')
        return y

# ---- OpenSMILE Normalized
def opensmile_features_NORM(file):
    
    try:
        y_raw, _ = librosa.load(file, sr = SR)
        
        if len(y_raw) < 2048:
            return None
        
        y = lufs_normalization(y_raw)
        
        features = smile.process_signal(y,SR)
        features_vector = features.reset_index(drop=True).iloc[0].to_dict()
        
        return features_vector
    except Exception as e:
        print(f"{e}")
        return None

# %%
def extract_opensmile_features(row):
    
    file = row["file"]
    
    full_vector = {}
    
    full_vector["file"] = file
    full_vector["label"] = row["emotion"]
    full_vector["split"] = row["split"]
    
    try:
        full_vector.update(opensmile_features_NORM(file))
        
        return full_vector
    except Exception as e:
        print(f"Extraction failed for {file}: {e}")
        return None
if __name__ == "__main__":
    
    features_list = list()
    
    for i, row in tqdm(df.iterrows(), total = df.shape[0]):
        
        features_vector = extract_opensmile_features(row)
        
        if features_vector is not None:
            features_list.append(features_vector)
            
    opensmile_features_df = pd.DataFrame(features_list)
# Out:
# 100%|██████████| 10678/10678 [08:23<00:00, 21.23it/s]

# %%
opensmile_features_df
# Out:
#                                   file    label  split  \
# 0        EMOITA/data/1613671614352.wav    anger  train
# 1        EMOITA/data/1613658275427.wav    anger  train
# 2        EMOITA/data/1613324357435.wav    anger  train
# 3        EMOITA/data/1614274086698.wav    anger  train
# 4        EMOITA/data/1612982146424.wav    anger  train
# ...                                ...      ...    ...
# 10673    TESS/data/OAF_cab_neutral.wav  neutral  train
# 10674  TESS/data/OAF_chain_disgust.wav  disgust  train
# 10675    TESS/data/OAF_jar_neutral.wav  neutral  train
# 10676      TESS/data/OAF_lot_angry.wav    anger  train
# 10677    TESS/data/YAF_met_neutral.wav  neutral  train
#
#        F0semitoneFrom27.5Hz_sma3nz_amean  \
# 0                              38.082653
# 1                              40.416210
# 2                              36.352093
# 3                              39.521694
# 4                              34.608627
# ...                                  ...
# 10673                          33.587734
# 10674                          32.935085
# 10675                          33.239281
# 10676                          39.684753
# 10677                          33.191181
#
#        F0semitoneFrom27.5Hz_sma3nz_stddevNorm  \
# 0                                    0.070298
# 1                                    0.120092
# 2                                    0.073894
# 3                                    0.132925
# 4                                    0.200003
# ...                                       ...
# 10673                                0.013397
# 10674                                0.090005
# 10675                                0.018863
# 10676                                0.053821
# 10677                                0.012730
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile20.0  \
# 0                                       36.122330
# 1                                       35.865879
# 2                                       32.938965
# 3                                       33.641102
# 4                                       30.287437
# ...                                           ...
# 10673                                   33.257698
# 10674                                   30.599874
# 10675                                   32.946789
# 10676                                   38.062737
# 10677                                   32.967422
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile50.0  \
# 0                                       39.153728
# 1                                       40.851280
# 2                                       37.385406
# 3                                       41.257381
# 4                                       33.143135
# ...                                           ...
# 10673                                   33.573410
# 10674                                   32.400887
# 10675                                   33.233498
# 10676                                   40.380672
# 10677                                   33.209473
#
#        F0semitoneFrom27.5Hz_sma3nz_percentile80.0  \
# 0                                       39.698322
# 1                                       43.643463
# 2                                       38.716221
# 3                                       44.157024
# 4                                       35.956718
# ...                                           ...
# 10673                                   33.801815
# 10674                                   35.419796
# 10675                                   33.606705
# 10676                                   41.368752
# 10677                                   33.540462
#
#        F0semitoneFrom27.5Hz_sma3nz_pctlrange0-2  \
# 0                                      3.575993
# 1                                      7.777584
# 2                                      5.777256
# 3                                     10.515923
# 4                                      5.669281
# ...                                         ...
# 10673                                  0.544117
# 10674                                  4.819921
# 10675                                  0.659916
# 10676                                  3.306015
# 10677                                  0.573040
#
#        F0semitoneFrom27.5Hz_sma3nz_meanRisingSlope  ...  \
# 0                                        13.681193  ...
# 1                                       134.605118  ...
# 2                                        36.450661  ...
# 3                                        95.706833  ...
# 4                                      2856.700928  ...
# ...                                            ...  ...
# 10673                                    11.546522  ...
# 10674                                    55.039375  ...
# 10675                                    21.448641  ...
# 10676                                    37.567173  ...
# 10677                                    47.889469  ...
#
#        slopeUV0-500_sma3nz_amean  slopeUV500-1500_sma3nz_amean  \
# 0                       0.043457                      0.024475
# 1                       0.082220                     -0.000170
# 2                       0.039326                      0.018660
# 3                       0.069682                      0.005402
# 4                       0.036268                      0.003279
# ...                          ...                           ...
# 10673                  -0.036753                      0.025578
# 10674                  -0.025782                      0.018447
# 10675                  -0.043057                      0.024206
# 10676                  -0.023124                      0.012767
# 10677                  -0.016006                      0.016694
#
#        spectralFluxUV_sma3nz_amean  loudnessPeaksPerSec  VoicedSegmentsPerSec  \
# 0                         0.013053             4.697987              2.097902
# 1                         0.249301             4.437870              2.702703
# 2                         0.035453             3.888889              2.298851
# 3                         0.113051             4.635762              2.702703
# 4                         0.147435             3.319502              1.271186
# ...                            ...                  ...                   ...
# 10673                     0.020441             2.645503              1.092896
# 10674                     0.033190             2.145923              1.754386
# 10675                     0.018796             1.960784              1.010101
# 10676                     0.059855             2.500000              1.290323
# 10677                     0.026538             3.045686              1.562500
#
#        MeanVoicedSegmentLengthSec  StddevVoicedSegmentLengthSec  \
# 0                        0.420000                      0.143527
# 1                        0.203333                      0.144760
# 2                        0.247500                      0.218561
# 3                        0.230000                      0.127574
# 4                        0.130000                      0.141657
# ...                           ...                           ...
# 10673                    0.655000                      0.335000
# 10674                    0.330000                      0.384773
# 10675                    0.810000                      0.370000
# 10676                    0.585000                      0.285000
# 10677                    0.420000                      0.398246
#
#        MeanUnvoicedSegmentLength  StddevUnvoicedSegmentLength  \
# 0                       0.055000                     0.035000
# 1                       0.144444                     0.229594
# 2                       0.220000                     0.165731
# 3                       0.186000                     0.204900
# 4                       0.475000                     0.397146
# ...                          ...                          ...
# 10673                   0.240000                     0.030000
# 10674                   0.215000                     0.127574
# 10675                   0.160000                     0.040000
# 10676                   0.110000                     0.028284
# 10677                   0.193333                     0.080554
#
#        equivalentSoundLevel_dBp
# 0                    -29.997206
# 1                    -17.485447
# 2                    -20.091305
# 3                    -22.264414
# 4                    -27.532452
# ...                         ...
# 10673                -37.568298
# 10674                -35.905819
# 10675                -37.107567
# 10676                -26.319199
# 10677                -33.309395
#
# [10678 rows x 91 columns]

# %%
output_dir = "TRAINING_ML"

if os.path.exists(output_dir):
    print("Folder already exists")
else:
    print("Folder created.")
    os.mkdir(output_dir)
    
output_path = os.path.join(output_dir, "OPENSMILE_FEATURES_NORM.pkl")

if os.path.exists(output_path):
    print("file already exists")
else:
    print("File created.")
    opensmile_features_df.to_pickle(output_path)
# Out:
# Folder already exists
# file already exists
